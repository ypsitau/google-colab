# %% [markdown]
# <a href="https://colab.research.google.com/github/ypsitau/google-colab/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gradio as gr

with gr.Blocks() as demo:
    gr.Markdown("# 🚀 AI 画像処理デモ")

    with gr.Row():
        with gr.Column():
            # インラインで変数に代入
            (img_input := gr.Image(label="入力画像"))
            (filter_type := gr.Dropdown(["モノクロ", "ぼかし", "輪郭抽出"], label="フィルタ"))
            (run_btn := gr.Button("実行", variant="primary"))

        with gr.Column():
            (img_output := gr.Image(label="出力結果"))

    # ロジックの紐付け
    # run_btn をクリックしたら、img_input と filter_type を関数に渡し、結果を img_output に出す
    # ※実際の画像処理関数を `fn` に指定します
    # run_btn.click(fn=my_process, inputs=[img_input, filter_type], outputs=img_output)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://8548a9a93ca98c6d7a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://8548a9a93ca98c6d7a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
