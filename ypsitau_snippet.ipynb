# %% [markdown]
# <a href="https://colab.research.google.com/github/ypsitau/google-colab/blob/main/ypsitau_snippet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare Google Drive

# %%
import google.colab import drive
drive.mount('/content/drive')
