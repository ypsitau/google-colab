# %% [markdown]
# <a href="https://colab.research.google.com/github/ypsitau/google-colab/blob/main/ypsitau-snippet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepare Google Drive

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.environ['TFDS_DATA_DIR'] = '/content/drive/MyDrive/tensorflow_datasets'
os.makedirs(os.environ['TFDS_DATA_DIR'], exist_ok=True)
